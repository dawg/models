# %%
# imports
import numpy as np
import os
import tqdm
import matplotlib.pyplot as plt
import torch

from torch.utils.data import DataLoader
from vusic.utils.separation_dataset import SeparationDataset
from vusic.utils.transforms import STFT, ISTFT
from torch.autograd import Variable

# %%
# init dataset
HOME = os.path.expanduser("~")
TEST = os.path.join(HOME, "storage", "separation", "pt_f_test")
TRAIN = os.path.join(HOME, "storage", "separation", "pt_f_train")
train_ds = SeparationDataset(TRAIN)
test_ds = SeparationDataset(TEST)
print(f"Training set contains {len(train_ds)} samples.")
print(f"Testing set contains {len(test_ds)} samples.")
# Out:
# Training set contains 100 samples.
# Testing set contains 50 samples.

# %%
# sample viewer
idx = 0

sample = train_ds[idx]

print(f"{sample['mix'][0].shape}, {sample['mix'][1].shape}, {sample['mix'][2].shape}")
      
magnitude, phase, ac = sample['mix']
      
w_size = 512
w_no = 600
      
f, subplot = plt.subplots(2, sharex=True)
      
subplot[0].set_title("STFT Sample: {}, Bin number: {}".format(train_ds.filenames[idx], w_no))
subplot[0].plot(range(w_size), np.transpose(magnitude.detach()[0, 0, :, w_no].numpy()))
subplot[0].set_xlim([0, w_size/4]);
subplot[0].set_ylabel("STFT Mix (Magnitude)")
subplot[1].plot(range(w_size), np.transpose(phase.detach()[0, 0, :, w_no].numpy()))
subplot[1].set_ylabel("STFT Mix (Phase)")
      
plt.show()
# Out:
# torch.Size([1, 1, 512, 16843]), torch.Size([1, 1, 512, 16843]), torch.Size([1, 1, 16843])

# %%
snapshot = 1000
fband = 20
red_dim = phase[0,0,:,:];

print(f"{red_dim.shape}")

for snapshot in range(1, 16, fband):
    plt.imshow(red_dim[0:fband,snapshot:(snapshot+fband)].detach().numpy(), cmap='cool', interpolation='nearest')
    plt.colorbar()
    plt.show()
# Out:
# torch.Size([512, 16843])

# %%
# configuration

dtype = torch.float

device = torch.device("cpu") # Uncomment this to run on CPU
# device = torch.device("cuda:0") # Uncomment this to run on GPU

# XXX can probably pass num_workers=4
# we also need to use a batch size of 1 since we have a dimension mismatch 
# (i.e. there's a different amount of samples depending on the song)
dataloader = DataLoader(train_ds, batch_size=1, shuffle=True)
testloader = DataLoader(test_ds, batch_size=1, shuffle=True)

# %%
# hyperparams

# %%
# main training loop
for i, sample in enumerate(dataloader):
    # do something here.
    print(f"Sample {i}: {sample['mix'][0].shape}");
# Out:
# Sample 0: torch.Size([1, 1, 1, 512, 16843])
# Sample 1: torch.Size([1, 1, 1, 512, 18165])
# Sample 2: torch.Size([1, 1, 1, 512, 22109])
# Sample 3: torch.Size([1, 1, 1, 512, 44297])
# Sample 4: torch.Size([1, 1, 1, 512, 18819])
# Sample 5: torch.Size([1, 1, 1, 512, 19965])
# Sample 6: torch.Size([1, 1, 1, 512, 27949])
# Sample 7: torch.Size([1, 1, 1, 512, 18329])
# Sample 8: torch.Size([1, 1, 1, 512, 54123])
# Sample 9: torch.Size([1, 1, 1, 512, 14255])
# Sample 10: torch.Size([1, 1, 1, 512, 20791])
# Sample 11: torch.Size([1, 1, 1, 512, 22249])
# Sample 12: torch.Size([1, 1, 1, 512, 21911])
# Sample 13: torch.Size([1, 1, 1, 512, 22433])
# Sample 14: torch.Size([1, 1, 1, 512, 20579])
# Sample 15: torch.Size([1, 1, 1, 512, 20839])
# Sample 16: torch.Size([1, 1, 1, 512, 27145])
# Sample 17: torch.Size([1, 1, 1, 512, 24395])
# Sample 18: torch.Size([1, 1, 1, 512, 25391])
# Sample 19: torch.Size([1, 1, 1, 512, 19313])
# Sample 20: torch.Size([1, 1, 1, 512, 17373])
# Sample 21: torch.Size([1, 1, 1, 512, 14517])
# Sample 22: torch.Size([1, 1, 1, 512, 22173])
# Sample 23: torch.Size([1, 1, 1, 512, 14749])
# Sample 24: torch.Size([1, 1, 1, 512, 16285])
# Sample 25: torch.Size([1, 1, 1, 512, 14071])
# Sample 26: torch.Size([1, 1, 1, 512, 28063])
# Sample 27: torch.Size([1, 1, 1, 512, 13703])
# Sample 28: torch.Size([1, 1, 1, 512, 2461])
# Sample 29: torch.Size([1, 1, 1, 512, 21805])
# Sample 30: torch.Size([1, 1, 1, 512, 15647])
# Sample 31: torch.Size([1, 1, 1, 512, 21275])
# Sample 32: torch.Size([1, 1, 1, 512, 20387])
# Sample 33: torch.Size([1, 1, 1, 512, 16419])
# Sample 34: torch.Size([1, 1, 1, 512, 6507])
# Sample 35: torch.Size([1, 1, 1, 512, 17697])
# Sample 36: torch.Size([1, 1, 1, 512, 23927])
# Sample 37: torch.Size([1, 1, 1, 512, 25977])
# Sample 38: torch.Size([1, 1, 1, 512, 21369])
# Sample 39: torch.Size([1, 1, 1, 512, 30603])
# Sample 40: torch.Size([1, 1, 1, 512, 24333])
# Sample 41: torch.Size([1, 1, 1, 512, 2217])
# Sample 42: torch.Size([1, 1, 1, 512, 21991])
# Sample 43: torch.Size([1, 1, 1, 512, 16935])
# Sample 44: torch.Size([1, 1, 1, 512, 2975])
# Sample 45: torch.Size([1, 1, 1, 512, 14457])
# Sample 46: torch.Size([1, 1, 1, 512, 3151])
# Sample 47: torch.Size([1, 1, 1, 512, 26697])
# Sample 48: torch.Size([1, 1, 1, 512, 22355])
# Sample 49: torch.Size([1, 1, 1, 512, 19021])
# Sample 50: torch.Size([1, 1, 1, 512, 16491])
# Sample 51: torch.Size([1, 1, 1, 512, 25367])
# Sample 52: torch.Size([1, 1, 1, 512, 20487])
# Sample 53: torch.Size([1, 1, 1, 512, 17605])
# Sample 54: torch.Size([1, 1, 1, 512, 35531])
# Sample 55: torch.Size([1, 1, 1, 512, 3115])
# Sample 56: torch.Size([1, 1, 1, 512, 1691])
# Sample 57: torch.Size([1, 1, 1, 512, 14923])
# Sample 58: torch.Size([1, 1, 1, 512, 33745])
# Sample 59: torch.Size([1, 1, 1, 512, 24617])
# Sample 60: torch.Size([1, 1, 1, 512, 19873])
# Sample 61: torch.Size([1, 1, 1, 512, 10731])
# Sample 62: torch.Size([1, 1, 1, 512, 19635])
# Sample 63: torch.Size([1, 1, 1, 512, 34327])
# Sample 64: torch.Size([1, 1, 1, 512, 17073])
# Sample 65: torch.Size([1, 1, 1, 512, 20987])
# Sample 66: torch.Size([1, 1, 1, 512, 21357])
# Sample 67: torch.Size([1, 1, 1, 512, 1111])
# Sample 68: torch.Size([1, 1, 1, 512, 23687])
# Sample 69: torch.Size([1, 1, 1, 512, 36285])
# Sample 70: torch.Size([1, 1, 1, 512, 15211])
# Sample 71: torch.Size([1, 1, 1, 512, 37473])
# Sample 72: torch.Size([1, 1, 1, 512, 24959])
# Sample 73: torch.Size([1, 1, 1, 512, 12639])
# Sample 74: torch.Size([1, 1, 1, 512, 18079])
# Sample 75: torch.Size([1, 1, 1, 512, 16521])
# Sample 76: torch.Size([1, 1, 1, 512, 14367])
# Sample 77: torch.Size([1, 1, 1, 512, 22057])
# Sample 78: torch.Size([1, 1, 1, 512, 20889])
# Sample 79: torch.Size([1, 1, 1, 512, 22771])
# Sample 80: torch.Size([1, 1, 1, 512, 3587])
# Sample 81: torch.Size([1, 1, 1, 512, 30741])
# Sample 82: torch.Size([1, 1, 1, 512, 16137])
# Sample 83: torch.Size([1, 1, 1, 512, 1487])
# Sample 84: torch.Size([1, 1, 1, 512, 9803])
# Sample 85: torch.Size([1, 1, 1, 512, 26013])
# Sample 86: torch.Size([1, 1, 1, 512, 20039])
# Sample 87: torch.Size([1, 1, 1, 512, 23087])
# Sample 88: torch.Size([1, 1, 1, 512, 15093])
# Sample 89: torch.Size([1, 1, 1, 512, 22317])
# Sample 90: torch.Size([1, 1, 1, 512, 20467])
# Sample 91: torch.Size([1, 1, 1, 512, 17411])
# Sample 92: torch.Size([1, 1, 1, 512, 26135])
# Sample 93: torch.Size([1, 1, 1, 512, 3163])
# Sample 94: torch.Size([1, 1, 1, 512, 1487])
# Sample 95: torch.Size([1, 1, 1, 512, 24915])
# Sample 96: torch.Size([1, 1, 1, 512, 36057])
# Sample 97: torch.Size([1, 1, 1, 512, 27289])
# Sample 98: torch.Size([1, 1, 1, 512, 23985])
# Sample 99: torch.Size([1, 1, 1, 512, 17889])
